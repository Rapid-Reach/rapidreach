# %%
import os
from anthropic import Anthropic

# Set up the Anthropic client with your API key
api_key = os.environ.get("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")
client = Anthropic(api_key=api_key)

# Define the prompt for the model
prompt = "\n\nHuman: What is the capital of France?"

# Set up the parameters for the API request
params = {
    "max_tokens_to_sample": 50,  # Limit the response to 50 tokens
    "model": "claude-v1",  # Use the Claude v1 model
    "prompt": prompt,  # Provide the prompt
}

# Send the API request to get the response
response = client.completions.create(**params)

# Print the generated response
print(response.completion)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 19
#      12 params = {
#      13     "max_tokens_to_sample": 50,  # Limit the response to 50 tokens
#      14     "model": "claude-v1",  # Use the Claude v1 model
#      15     "prompt": prompt,  # Provide the prompt
#      16 }
#      18 # Send the API request to get the response
# ---> 19 response = client.completions.create(**params)
#      21 # Print the generated response
#      22 print(response.completion)
#
# File C:\programs\miniconda3\envs\rapidreach\Lib\site-packages\anthropic\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# ...
